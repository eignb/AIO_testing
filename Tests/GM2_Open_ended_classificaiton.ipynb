# %% [markdown]
# # Open ended training test
# In this test you will be given two hours to produce the best model you are able to. At the end of the time you will all test your model on reserved data to see which performs the best.
# </br>
# We will be training our models for chest X-ray classification.

# %% [markdown]
# ## Dataset
# For this we will use the ChestMNIST dataset from the medMNIST library : https://medmnist.com/

# %%
# TODO install the medmnist libary
from medmnist import ChestMNIST
train_dataset = ChestMNIST(split='train')

# %%
# TODO use this section to explore your dataset -- get its shape, number of classes, and perhaps display an example to perhaps understand what assumptions you can make

# %%
# TODO if you do any preprocessing you should do it here

# %% [markdown]
# ## Model
# Here you should define your model. You are allowed to use PyTorch and Numpy.

# %%
# TODO define a model -- it may be any kind that you see fit

# %% [markdown]
# ## Training
# Here you will train your model, you may use any libraries to help with this

# %%
# TODO train your model

# %% [markdown]
# ## Evaluation
# Now you must write some code to evaluate your model -- YOU MAY NOT USE THE TESTING DATA SPLIT

# %%
# TODO write a function to test the accuracy (and any other metric you see fit) here.

# %% [markdown]
# ## Refinement
# Now you should try to get the best performance possible. Your final evaulation will be on the test dataset, but you may not access it until the final test.

# %%
# TODO using any method of your choosing, produce the best classifier for the ChestMNIST dataset.
